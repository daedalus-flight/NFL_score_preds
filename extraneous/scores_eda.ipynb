# %%
import pandas as pd

# %%
scores = pd.read_csv('./data/spreadspoke_scores.csv')

# %%
scores.head()
# Out:
#   schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0    09/02/1966             1966             1             False
# 1    09/03/1966             1966             1             False
# 2    09/04/1966             1966             1             False
# 3    09/09/1966             1966             2             False
# 4    09/10/1966             1966             1             False
#
#             team_home  score_home  score_away        team_away  \
# 0      Miami Dolphins          14          23  Oakland Raiders
# 1      Houston Oilers          45           7   Denver Broncos
# 2  San Diego Chargers          27           7    Buffalo Bills
# 3      Miami Dolphins          14          19    New York Jets
# 4   Green Bay Packers          24           3  Baltimore Colts
#
#   team_favorite_id  spread_favorite over_under_line         stadium  \
# 0              NaN              NaN             NaN     Orange Bowl
# ...

# %%
scores05 = pd.DataFrame(scores[scores['schedule_season']>= 2005])

# %%
scores05.head()
# Out:
#      schedule_date  schedule_season schedule_week  schedule_playoff  \
# 8673    09/08/2005             2005             1             False
# 8674    09/11/2005             2005             1             False
# 8675    09/11/2005             2005             1             False
# 8676    09/11/2005             2005             1             False
# 8677    09/11/2005             2005             1             False
#
#                  team_home  score_home  score_away           team_away  \
# 8673  New England Patriots          30          20     Oakland Raiders
# 8674      Baltimore Ravens           7          24  Indianapolis Colts
# 8675         Buffalo Bills          22           7      Houston Texans
# 8676     Carolina Panthers          20          23  New Orleans Saints
# 8677      Cleveland Browns          13          27  Cincinnati Bengals
#
#      team_favorite_id  spread_favorite over_under_line  \
# 8673               NE             -7.5              50
# ...

# %%
scores05[scores05['schedule_season'] == 2019].head()
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 12411    2019-09-05             2019             1             False
# 12412    2019-09-08             2019             1             False
# 12413    2019-09-08             2019             1             False
# 12414    2019-09-08             2019             1             False
# 12415    2019-09-08             2019             1             False
#
#                team_home  score_home  score_away          team_away  \
# 12411      Chicago Bears           3          10  Green Bay Packers
# 12412  Arizona Cardinals          27          27      Detroit Lions
# 12413  Carolina Panthers          27          30   Los Angeles Rams
# 12414   Cleveland Browns          13          43   Tennessee Titans
# 12415     Dallas Cowboys          35          17    New York Giants
#
#       team_favorite_id  spread_favorite over_under_line  \
# 12411              CHI             -3.0            46.5
# ...

# %%
scores05['schedule_date'] = pd.to_datetime(scores05['schedule_date'])

# %%
scores05[scores05['schedule_date'] == '2020-02-02']
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 12677    2020-02-02             2019     Superbowl              True
#
#                 team_home  score_home  score_away            team_away  \
# 12677  Kansas City Chiefs          31          20  San Francisco 49ers
#
#       team_favorite_id  spread_favorite over_under_line            stadium  \
# 12677               KC             -1.5              53  Hard Rock Stadium
#
#        stadium_neutral  weather_temperature  weather_wind_mph  \
# 12677             True                  NaN               NaN
#
#       weather_humidity weather_detail
# 12677              NaN            NaN

# %%
scores05.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4005 entries, 8673 to 12677
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   schedule_date        4005 non-null   datetime64[ns]
#  1   schedule_season      4005 non-null   int64
#  2   schedule_week        4005 non-null   object
#  3   schedule_playoff     4005 non-null   bool
#  4   team_home            4005 non-null   object
#  5   score_home           4005 non-null   int64
#  6   score_away           4005 non-null   int64
#  7   team_away            4005 non-null   object
#  8   team_favorite_id     4005 non-null   object
#  9   spread_favorite      4005 non-null   float64
#  10  over_under_line      4005 non-null   object
#  11  stadium              4005 non-null   object
#  12  stadium_neutral      4005 non-null   bool
#  13  weather_temperature  3721 non-null   float64
#  14  weather_wind_mph     3721 non-null   float64
# ...

# %% [markdown]
# ### will decide on weather later

# %%
scores05.shape
# Out:
# (4005, 17)
