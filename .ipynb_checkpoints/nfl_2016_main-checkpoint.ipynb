# %%
import pandas as pd

# %%
nfl = pd.read_csv('./data/spreadspoke_110820.csv', index_col = "schedule_date", parse_dates = True)

# %% [markdown]
# ### Data starts in 2011 Season

# %%
nfl = pd.DataFrame(nfl.loc['2011-09-01':'2020-11-02'])

# %%
nfl['over_under_line'] = nfl['over_under_line'].astype(float)

# %%
nfl16 = nfl.iloc[:, :7]

# %% [markdown]
# ### Working on only 2016

# %%
nfl16 = pd.DataFrame(nfl16.loc['2016-09-01':'2017-01-01'])

# %%
nfl16.drop(columns = 'schedule_playoff',inplace=True)

# %%
nfl16['margin'] = nfl16['score_home'] - nfl16['score_away']

# %% [markdown]
# - changing team names to city abbreviations

# %%
def desc_to_id(id):

    id_dict = {
        'Atlanta Falcons': 'ATL',
        'Chicago Bears': 'CHI',
        'Cleveland Browns': 'CLE',
        'Green Bay Packers': "GB",
        'Indianapolis Colts':'IND',
        'Jacksonville Jaguars':'JAX',
        'New Orleans Saints': 'NO',
        'New York Jets':'NYJ',
        'Philadelphia Eagles':'PHI',
        'Seattle Seahawks':'SEA',
        'St. Louis Rams': 'LAR',
        'Tampa Bay Buccaneers':'TB',
        'Tennessee Titans':'TEN',
        'Washington Redskins':'WAS',
        'Denver Broncos':'DEN',
        'Baltimore Ravens':'BAL',
        'Buffalo Bills':'BUF',
        'Carolina Panthers':'CAR',
        'Cincinnati Bengals': 'CIN',
        'Detroit Lions': 'DET',
        'Kansas City Chiefs': 'KC',
        'Miami Dolphins': 'MIA',
        'Minnesota Vikings':'MIN',
        'New England Patriots':'NE',
        'New York Giants':'NYG',
        'San Francisco 49ers':'SF',
        'Dallas Cowboys': 'DAL',
        'Oakland Raiders': 'OAK',
        'Pittsburgh Steelers':'PIT',
        'San Diego Chargers':'LAC',
        'Arizona Cardinals': 'ARI',
        'Houston Texans':'HOU',
        'Los Angeles Rams':'LAR',
        'Los Angeles Chargers':'LAC'
    }
    
    try:
        return id_dict[id]
    except:
        return 'CHECK!'

# %%
nfl16['team_away'] = nfl16['team_away'].apply(desc_to_id)
nfl16['team_home'] = nfl16['team_home'].apply(desc_to_id)

# %% [markdown]
# - 32 teams so 16 rows per week

# %%
nfl16.shape
# Out:
# (256, 7)

# %%
nfl16['home_team']= nfl16['team_home']
nfl16.tail(17)
# Out:
#                schedule_season schedule_week team_home  score_home  \
# schedule_date
# 2016-12-26                2016            16       DAL        42.0
# 2017-01-01                2016            17       ATL        38.0
# 2017-01-01                2016            17       CIN        27.0
# 2017-01-01                2016            17       DEN        24.0
# 2017-01-01                2016            17       DET        24.0
# 2017-01-01                2016            17       IND        24.0
# 2017-01-01                2016            17       LAR         6.0
# 2017-01-01                2016            17       MIA        14.0
# 2017-01-01                2016            17       MIN        38.0
# 2017-01-01                2016            17       NYJ        30.0
# 2017-01-01                2016            17       PHI        27.0
# 2017-01-01                2016            17       PIT        27.0
# 2017-01-01                2016            17       LAC        27.0
# 2017-01-01                2016            17        SF        23.0
# 2017-01-01                2016            17        TB        17.0
# 2017-01-01                2016            17       TEN        24.0
# 2017-01-01                2016            17       WAS        10.0
#
#                score_away team_away  margin home_team
# schedule_date
# 2016-12-26           21.0       DET    21.0       DAL
# 2017-01-01           32.0        NO     6.0       ATL
# 2017-01-01           10.0       BAL    17.0       CIN
# 2017-01-01            6.0       OAK    18.0       DEN
# 2017-01-01           31.0        GB    -7.0       DET
# 2017-01-01           20.0       JAX     4.0       IND
# 2017-01-01           44.0       ARI   -38.0       LAR
# 2017-01-01           35.0        NE   -21.0       MIA
# 2017-01-01           10.0       CHI    28.0       MIN
# 2017-01-01           10.0       BUF    20.0       NYJ
# 2017-01-01           13.0       DAL    14.0       PHI
# 2017-01-01           24.0       CLE     3.0       PIT
# 2017-01-01           37.0        KC   -10.0       LAC
# 2017-01-01           25.0       SEA    -2.0        SF
# 2017-01-01           16.0       CAR     1.0        TB
# 2017-01-01           17.0       HOU     7.0       TEN
# 2017-01-01           19.0       NYG    -9.0       WAS

# %%
#nfl16['id'] = nfl16['schedule_season'].astype(str) + nfl16['team_home'] + nfl16['schedule_week']

# %%
nfl16.head()
# Out:
#                schedule_season schedule_week team_home  score_home  \
# schedule_date
# 2016-09-08                2016             1       DEN        21.0
# 2016-09-11                2016             1       ARI        21.0
# 2016-09-11                2016             1       ATL        24.0
# 2016-09-11                2016             1       BAL        13.0
# 2016-09-11                2016             1       DAL        19.0
#
#                score_away team_away  margin home_team
# schedule_date
# 2016-09-08           20.0       CAR     1.0       DEN
# 2016-09-11           23.0        NE    -2.0       ARI
# 2016-09-11           31.0        TB    -7.0       ATL
# 2016-09-11            7.0       BUF     6.0       BAL
# 2016-09-11           20.0       NYG    -1.0       DAL

# %% [markdown]
# ### need to cut to week 6 here?

# %%
#nfl16_a[nfl16_a['schedule_week']=='6']

# %%
# h is for home designation
nfl16_h = nfl16.rename(columns= {
    'team_home': 'team',
    'score_home': 'score',
    'score_away': 'opponent_score',    
})

# %% [markdown]
# - needed to add unique id

# %%
nfl16_h['id'] = nfl16_h['schedule_season'].astype(str) + nfl16_h['team'] + nfl16_h['schedule_week']

# %%
nfl16_h.head()
# Out:
#                schedule_season schedule_week team  score  opponent_score  \
# schedule_date
# 2016-09-08                2016             1  DEN   21.0            20.0
# 2016-09-11                2016             1  ARI   21.0            23.0
# 2016-09-11                2016             1  ATL   24.0            31.0
# 2016-09-11                2016             1  BAL   13.0             7.0
# 2016-09-11                2016             1  DAL   19.0            20.0
#
#               team_away  margin home_team        id
# schedule_date
# 2016-09-08          CAR     1.0       DEN  2016DEN1
# 2016-09-11           NE    -2.0       ARI  2016ARI1
# 2016-09-11           TB    -7.0       ATL  2016ATL1
# 2016-09-11          BUF     6.0       BAL  2016BAL1
# 2016-09-11          NYG    -1.0       DAL  2016DAL1

# %%
nfl16_h.drop(columns = 'team_away', inplace=True)

# %%
nfl16_h.shape
# Out:
# (256, 8)

# %%
# a is for home designation
nfl16_a = nfl16.rename(columns= {
    'team_away': 'team',
    'score_away': 'score',
    'score_home': 'opponent_score',    
})

# %%
nfl16_a.head()
# Out:
#                schedule_season schedule_week team_home  opponent_score  score  \
# schedule_date
# 2016-09-08                2016             1       DEN            21.0   20.0
# 2016-09-11                2016             1       ARI            21.0   23.0
# 2016-09-11                2016             1       ATL            24.0   31.0
# 2016-09-11                2016             1       BAL            13.0    7.0
# 2016-09-11                2016             1       DAL            19.0   20.0
#
#               team  margin home_team
# schedule_date
# 2016-09-08     CAR     1.0       DEN
# 2016-09-11      NE    -2.0       ARI
# 2016-09-11      TB    -7.0       ATL
# 2016-09-11     BUF     6.0       BAL
# 2016-09-11     NYG    -1.0       DAL

# %% [markdown]
# - need to add unique "id"

# %%
nfl16_a['id'] = nfl16_a['schedule_season'].astype(str) + nfl16_a['team'] + nfl16_a['schedule_week']

# %%
nfl16_a.drop(columns='team_home', inplace=True)

# %%
nfl16_a['margin'] = nfl16_a['score'] - nfl16_a['opponent_score']

# %%
nfl16_a.shape
# Out:
# (256, 8)

# %%
nfl16_a.head()
# Out:
#                schedule_season schedule_week  opponent_score  score team  \
# schedule_date
# 2016-09-08                2016             1            21.0   20.0  CAR
# 2016-09-11                2016             1            21.0   23.0   NE
# 2016-09-11                2016             1            24.0   31.0   TB
# 2016-09-11                2016             1            13.0    7.0  BUF
# 2016-09-11                2016             1            19.0   20.0  NYG
#
#                margin home_team        id
# schedule_date
# 2016-09-08       -1.0       DEN  2016CAR1
# 2016-09-11        2.0       ARI   2016NE1
# 2016-09-11        7.0       ATL   2016TB1
# 2016-09-11       -6.0       BAL  2016BUF1
# 2016-09-11        1.0       DAL  2016NYG1

# %%
nfl16_a = nfl16_a[['id','schedule_season', 'schedule_week', 'team', 'score', 'opponent_score', 'margin', 'home_team']]

# %%
#nfl16_a[nfl16_a['schedule_week']=='6']
#nfl16_a.shape #(256,8)
nfl16_a.head()
# Out:
#                      id  schedule_season schedule_week team  score  \
# schedule_date
# 2016-09-08     2016CAR1             2016             1  CAR   20.0
# 2016-09-11      2016NE1             2016             1   NE   23.0
# 2016-09-11      2016TB1             2016             1   TB   31.0
# 2016-09-11     2016BUF1             2016             1  BUF    7.0
# 2016-09-11     2016NYG1             2016             1  NYG   20.0
#
#                opponent_score  margin home_team
# schedule_date
# 2016-09-08               21.0    -1.0       DEN
# 2016-09-11               21.0     2.0       ARI
# 2016-09-11               24.0     7.0       ATL
# 2016-09-11               13.0    -6.0       BAL
# 2016-09-11               19.0     1.0       DAL

# %%
nfl16_ha = pd.concat([nfl16_h, nfl16_a], axis=0, join ='inner')

# %%
nfl16_ha.sort_values(by = ['schedule_date','team'],inplace =True)

# %%
nfl16_ha = nfl16_ha.reset_index()
nfl16_ha.tail()
# Out:
#     schedule_date  schedule_season schedule_week team  score  opponent_score  \
# 507    2017-01-01             2016            17  SEA   25.0            23.0
# 508    2017-01-01             2016            17   SF   23.0            25.0
# 509    2017-01-01             2016            17   TB   17.0            16.0
# 510    2017-01-01             2016            17  TEN   24.0            17.0
# 511    2017-01-01             2016            17  WAS   10.0            19.0
#
#      margin home_team         id
# 507     2.0        SF  2016SEA17
# 508    -2.0        SF   2016SF17
# 509     1.0        TB   2016TB17
# 510     7.0       TEN  2016TEN17
# 511    -9.0       WAS  2016WAS17

# %%
nfl16_ha.shape
# Out:
# (512, 9)

# %% [markdown]
# ### changing to week 6 here

# %%
nfl16_ha.nunique()
# Out:
# schedule_date       51
# schedule_season      1
# schedule_week       17
# team                32
# score               46
# opponent_score      46
# margin              67
# home_team           32
# id                 512
# dtype: int64

# %%
nfl16_ha.shape
# Out:
# (512, 9)

# %%
#nfl16_ha =pd.DataFrame(nfl16_ha.loc[:'2016-10-18'])

# %%
nfl16_ha.tail(2)
# Out:
#     schedule_date  schedule_season schedule_week team  score  opponent_score  \
# 510    2017-01-01             2016            17  TEN   24.0            17.0
# 511    2017-01-01             2016            17  WAS   10.0            19.0
#
#      margin home_team         id
# 510     7.0       TEN  2016TEN17
# 511    -9.0       WAS  2016WAS17

# %%
nfl16_ha.shape
# Out:
# (512, 9)

# %% [markdown]
# ##### Brings in the yardage file

# %%
nfl16_yards = pd.read_csv('./data/nfl16_yards.csv', index_col=0)

# %%
nfl16_yards.head()
# Out:
#    game_number team  passing_yards  rushing_yards
# 0            1  ARI            271             92
# 1            1  ATL            334             52
# 2            1  BAL            258             83
# 3            1  BUF            111             65
# 4            1  CAR            194            157

# %%
nfl16_yards['id'] = '2016'+ nfl16_yards['team'] + nfl16_yards['game_number'].astype(str)

# %% [markdown]
# ### nfl16_yards is here is 2016 passing and rushing yards gained per game

# %%
nfl16_yards.head()
# Out:
#    game_number team  passing_yards  rushing_yards        id
# 0            1  ARI            271             92  2016ARI1
# 1            1  ATL            334             52  2016ATL1
# 2            1  BAL            258             83  2016BAL1
# 3            1  BUF            111             65  2016BUF1
# 4            1  CAR            194            157  2016CAR1

# %%
nfl16_yards['team'].unique()
# Out:
# array(['ARI', 'ATL', 'BAL', 'BUF', 'CAR', 'CHI', 'CIN', 'CLE', 'DAL',
#        'DEN', 'DET', 'GNB', 'HOU', 'IND', 'JAX', 'KAN', 'LAR', 'MIA',
#        'MIN', 'NOR', 'NWE', 'NYG', 'NYJ', 'OAK', 'PHI', 'PIT', 'SDG',
#        'SEA', 'SFO', 'TAM', 'TEN', 'WAS'], dtype=object)

# %% [markdown]
# ### nfl16_ha is 2016 points scored and allowed

# %%
nfl16_ha.head()
# Out:
#   schedule_date  schedule_season schedule_week team  score  opponent_score  \
# 0    2016-09-08             2016             1  CAR   20.0            21.0
# 1    2016-09-08             2016             1  DEN   21.0            20.0
# 2    2016-09-11             2016             1  ARI   21.0            23.0
# 3    2016-09-11             2016             1  ATL   24.0            31.0
# 4    2016-09-11             2016             1  BAL   13.0             7.0
#
#    margin home_team        id
# 0    -1.0       DEN  2016CAR1
# 1     1.0       DEN  2016DEN1
# 2    -2.0       ARI  2016ARI1
# 3    -7.0       ATL  2016ATL1
# 4     6.0       BAL  2016BAL1

# %%
nfl16_agg = pd.merge(nfl16_ha, nfl16_yards, on = 'id')

# %%
nfl16_agg.sort_values('schedule_date').head(32)
# Out:
#    schedule_date  schedule_season schedule_week team_x  score  opponent_score  \
# 0     2016-09-08             2016             1    CAR   20.0            21.0
# 1     2016-09-08             2016             1    DEN   21.0            20.0
# 21    2016-09-11             2016             1    TEN   16.0            25.0
# 20    2016-09-11             2016             1    SEA   12.0            10.0
# 19    2016-09-11             2016             1    PHI   29.0            10.0
# 17    2016-09-11             2016             1    NYJ   22.0            23.0
# 16    2016-09-11             2016             1    NYG   20.0            19.0
# 15    2016-09-11             2016             1    MIN   25.0            16.0
# 14    2016-09-11             2016             1    MIA   10.0            12.0
# 13    2016-09-11             2016             1    JAX   23.0            27.0
# 12    2016-09-11             2016             1    IND   35.0            39.0
# 18    2016-09-11             2016             1    OAK   35.0            34.0
# 10    2016-09-11             2016             1    DET   39.0            35.0
# 9     2016-09-11             2016             1    DAL   19.0            20.0
# 8     2016-09-11             2016             1    CLE   10.0            29.0
# 7     2016-09-11             2016             1    CIN   23.0            22.0
# 6     2016-09-11             2016             1    CHI   14.0            23.0
# 5     2016-09-11             2016             1    BUF    7.0            13.0
# 11    2016-09-11             2016             1    HOU   23.0            14.0
# 4     2016-09-11             2016             1    BAL   13.0             7.0
# 3     2016-09-11             2016             1    ATL   24.0            31.0
# 2     2016-09-11             2016             1    ARI   21.0            23.0
# 23    2016-09-12             2016             1    PIT   38.0            16.0
# 24    2016-09-12             2016             1    WAS   16.0            38.0
# 22    2016-09-12             2016             1    LAR    0.0            28.0
# 25    2016-09-15             2016             2    BUF   31.0            37.0
# 26    2016-09-15             2016             2    NYJ   37.0            31.0
# 38    2016-09-18             2016             2    JAX   14.0            38.0
# 47    2016-09-18             2016             2    WAS   23.0            27.0
# 46    2016-09-18             2016             2    TEN   16.0            15.0
# 45    2016-09-18             2016             2    SEA    3.0             9.0
# 44    2016-09-18             2016             2    PIT   24.0            16.0
#
#     margin home_team        id  game_number team_y  passing_yards  \
# 0     -1.0       DEN  2016CAR1            1    CAR            194
# 1      1.0       DEN  2016DEN1            1    DEN            178
# 21    -9.0       TEN  2016TEN1            1    TEN            271
# 20     2.0       SEA  2016SEA1            1    SEA            258
# 19    19.0       PHI  2016PHI1            1    PHI            278
# 17    -1.0       NYJ  2016NYJ1            1    NYJ            189
# 16     1.0       DAL  2016NYG1            1    NYG            207
# 15     9.0       TEN  2016MIN1            1    MIN            236
# 14    -2.0       SEA  2016MIA1            1    MIA            186
# 13    -4.0       JAX  2016JAX1            1    JAX            320
# 12    -4.0       IND  2016IND1            1    IND            385
# 18     1.0        NO  2016OAK1            1    OAK            319
# 10     4.0       IND  2016DET1            1    DET            340
# 9     -1.0       DAL  2016DAL1            1    DAL            227
# 8    -19.0       PHI  2016CLE1            1    CLE            190
# 7      1.0       NYJ  2016CIN1            1    CIN            366
# 6     -9.0       HOU  2016CHI1            1    CHI            216
# 5     -6.0       BAL  2016BUF1            1    BUF            111
# 11     9.0       HOU  2016HOU1            1    HOU            231
# 4      6.0       BAL  2016BAL1            1    BAL            258
# 3     -7.0       ATL  2016ATL1            1    ATL            334
# 2     -2.0       ARI  2016ARI1            1    ARI            271
# 23    22.0       WAS  2016PIT1            1    PIT            300
# 24   -22.0       WAS  2016WAS1            1    WAS            329
# 22   -28.0        SF  2016LAR1            1    LAR            130
# 25    -6.0       BUF  2016BUF2            2    BUF            307
# 26     6.0       BUF  2016NYJ2            2    NYJ            374
# 38   -24.0       LAC  2016JAX2            2    JAX            329
# 47    -4.0       WAS  2016WAS2            2    WAS            364
# 46     1.0       DET  2016TEN2            2    TEN            238
# 45    -6.0       LAR  2016SEA2            2    SEA            254
# 44     8.0       PIT  2016PIT2            2    PIT            259
#
#     rushing_yards
# 0             157
# 1             148
# 21             64
# 20            112
# 19            133
# 17            152
# 16            113
# 15             65
# 14             64
# 13             48
# 12             82
# 18            167
# 10            116
# 9             101
# 8             120
# 7              57
# 6              73
# 5              65
# 11            129
# 4              83
# 3              52
# 2              92
# 23            147
# 24             55
# 22             65
# 25             86
# 26            123
# 38             69
# 47             82
# 46            139
# 45             67
# 44            124

# %%
nfl16_agg[nfl16_agg['schedule_week'] =='1'].sort_values('home_team')
# Out:
#    schedule_date  schedule_season schedule_week team_x  score  opponent_score  \
# 2     2016-09-11             2016             1    ARI   21.0            23.0
# 3     2016-09-11             2016             1    ATL   24.0            31.0
# 4     2016-09-11             2016             1    BAL   13.0             7.0
# 5     2016-09-11             2016             1    BUF    7.0            13.0
# 16    2016-09-11             2016             1    NYG   20.0            19.0
# 9     2016-09-11             2016             1    DAL   19.0            20.0
# 0     2016-09-08             2016             1    CAR   20.0            21.0
# 1     2016-09-08             2016             1    DEN   21.0            20.0
# 6     2016-09-11             2016             1    CHI   14.0            23.0
# 11    2016-09-11             2016             1    HOU   23.0            14.0
# 12    2016-09-11             2016             1    IND   35.0            39.0
# 10    2016-09-11             2016             1    DET   39.0            35.0
# 13    2016-09-11             2016             1    JAX   23.0            27.0
# 18    2016-09-11             2016             1    OAK   35.0            34.0
# 7     2016-09-11             2016             1    CIN   23.0            22.0
# 17    2016-09-11             2016             1    NYJ   22.0            23.0
# 8     2016-09-11             2016             1    CLE   10.0            29.0
# 19    2016-09-11             2016             1    PHI   29.0            10.0
# 14    2016-09-11             2016             1    MIA   10.0            12.0
# 20    2016-09-11             2016             1    SEA   12.0            10.0
# 22    2016-09-12             2016             1    LAR    0.0            28.0
# 15    2016-09-11             2016             1    MIN   25.0            16.0
# 21    2016-09-11             2016             1    TEN   16.0            25.0
# 23    2016-09-12             2016             1    PIT   38.0            16.0
# 24    2016-09-12             2016             1    WAS   16.0            38.0
#
#     margin home_team        id  game_number team_y  passing_yards  \
# 2     -2.0       ARI  2016ARI1            1    ARI            271
# 3     -7.0       ATL  2016ATL1            1    ATL            334
# 4      6.0       BAL  2016BAL1            1    BAL            258
# 5     -6.0       BAL  2016BUF1            1    BUF            111
# 16     1.0       DAL  2016NYG1            1    NYG            207
# 9     -1.0       DAL  2016DAL1            1    DAL            227
# 0     -1.0       DEN  2016CAR1            1    CAR            194
# 1      1.0       DEN  2016DEN1            1    DEN            178
# 6     -9.0       HOU  2016CHI1            1    CHI            216
# 11     9.0       HOU  2016HOU1            1    HOU            231
# 12    -4.0       IND  2016IND1            1    IND            385
# 10     4.0       IND  2016DET1            1    DET            340
# 13    -4.0       JAX  2016JAX1            1    JAX            320
# 18     1.0        NO  2016OAK1            1    OAK            319
# 7      1.0       NYJ  2016CIN1            1    CIN            366
# 17    -1.0       NYJ  2016NYJ1            1    NYJ            189
# 8    -19.0       PHI  2016CLE1            1    CLE            190
# 19    19.0       PHI  2016PHI1            1    PHI            278
# 14    -2.0       SEA  2016MIA1            1    MIA            186
# 20     2.0       SEA  2016SEA1            1    SEA            258
# 22   -28.0        SF  2016LAR1            1    LAR            130
# 15     9.0       TEN  2016MIN1            1    MIN            236
# 21    -9.0       TEN  2016TEN1            1    TEN            271
# 23    22.0       WAS  2016PIT1            1    PIT            300
# 24   -22.0       WAS  2016WAS1            1    WAS            329
#
#     rushing_yards
# 2              92
# 3              52
# 4              83
# 5              65
# 16            113
# 9             101
# 0             157
# 1             148
# 6              73
# 11            129
# 12             82
# 10            116
# 13             48
# 18            167
# 7              57
# 17            152
# 8             120
# 19            133
# 14             64
# 20            112
# 22             65
# 15             65
# 21             64
# 23            147
# 24             55

# %%
nfl16_agg.to_csv('nfl16agg.csv')

# %%
nfl16w6_yards = pd.DataFrame(nfl16_yards[nfl16_yards['game_number']<=6])
nfl16w6_yards.tail()
# Out:
#      game_number team  passing_yards  rushing_yards        id
# 187            6  SEA            225             52  2016SEA6
# 188            6  SFO            187            133  2016SFO6
# 189            6  TAM            269            249  2016TAM6
# 190            6  TEN            284            137  2016TEN6
# 191            6  WAS            263            230  2016WAS6

# %%
nfl16w6_yards.sort_values(by = ['game_number','team'],inplace =True)

# %%
nfl16w6_yards.tail()
# Out:
#      game_number team  passing_yards  rushing_yards        id
# 187            6  SEA            225             52  2016SEA6
# 188            6  SFO            187            133  2016SFO6
# 189            6  TAM            269            249  2016TAM6
# 190            6  TEN            284            137  2016TEN6
# 191            6  WAS            263            230  2016WAS6

# %%
yards16_f6 = nfl16w6_yards.groupby('team').sum().reset_index()

# %%
yards16_f6.shape
# Out:
# (32, 4)

# %%
pf_pa.head(32)
# Out:
#    team  score  opponent_score  margin
# 0   ARI  418.0           362.0    56.0
# 1   ATL  540.0           406.0   134.0
# 2   BAL  343.0           321.0    22.0
# 3   BUF  399.0           378.0    21.0
# 4   CAR  369.0           402.0   -33.0
# 5   CHI  279.0           399.0  -120.0
# 6   CIN  325.0           315.0    10.0
# 7   CLE  264.0           452.0  -188.0
# 8   DAL  421.0           306.0   115.0
# 9   DEN  333.0           297.0    36.0
# 10  DET  346.0           358.0   -12.0
# 11   GB  432.0           388.0    44.0
# 12  HOU  279.0           328.0   -49.0
# 13  IND  411.0           392.0    19.0
# 14  JAX  318.0           400.0   -82.0
# 15   KC  389.0           311.0    78.0
# 16  LAC  410.0           423.0   -13.0
# 17  LAR  224.0           394.0  -170.0
# 18  MIA  363.0           380.0   -17.0
# 19  MIN  327.0           307.0    20.0
# 20   NE  441.0           250.0   191.0
# 21   NO  469.0           454.0    15.0
# 22  NYG  310.0           284.0    26.0
# 23  NYJ  275.0           409.0  -134.0
# 24  OAK  416.0           385.0    31.0
# 25  PHI  367.0           331.0    36.0
# 26  PIT  399.0           327.0    72.0
# 27  SEA  354.0           292.0    62.0
# 28   SF  309.0           480.0  -171.0
# 29   TB  354.0           369.0   -15.0
# 30  TEN  381.0           378.0     3.0
# 31  WAS  396.0           383.0    13.0

# %%
pf_pa = pd.DataFrame(nfl16_ha.groupby('team').sum()[['score','opponent_score','margin']])
#pfa = pd.DataFrame(nfl16_ha.groupby('team').sum()[['score_away']])
#pfh.reset_index(inplace = True)
pf_pa.reset_index(inplace = True)

# %%
nfl16_agg = pd.concat([pf_pa, yards16_f6], axis=1, join ='inner')

# %%
nfl16_agg.shape
# Out:
# (32, 8)

# %%
nfl16_agg1 = pd.concat([nfl16_agg, nfl_target['score']], axis=1, join ='inner')

# %%
nfl16_agg1.count()
# Out:
# team              30
# score             30
# opponent_score    30
# margin            30
# team              30
# game_number       30
# passing_yards     30
# rushing_yards     30
# score             30
# dtype: int64

# %%
nfl_target = pd.DataFrame(nfl16_ha[nfl16_ha['schedule_week']=='6'].sort_values(by='team')).reset_index()

# %%
nfl_target.shape
# Out:
# (30, 10)

# %%
nfl16_agg1.tail()
# Out:
#    team  score  opponent_score  margin team  game_number  passing_yards  \
# 25  PHI  367.0           331.0    36.0  PIT           21           1685
# 26  PIT  399.0           327.0    72.0  SDG           21           1647
# 27  SEA  354.0           292.0    62.0  SEA           21           1624
# 28   SF  309.0           480.0  -171.0  SFO           21           1077
# 29   TB  354.0           369.0   -15.0  TAM           21           1596
#
#     rushing_yards  score
# 25            638   15.0
# 26            551   26.0
# 27            496   16.0
# 28            740   28.0
# 29            692   27.0

# %%
# nfl16_agg1.rename(columns= {'score':'target'})
# nfl16_agg1
